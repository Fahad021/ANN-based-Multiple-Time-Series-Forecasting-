# %%
import os
import pandas as pd
data_dir = r'C:\Users\54651\Downloads\smeco forecasting'
file = 'AMI_transposed_with_temps.csv'
df = pd.read_csv(os.path.join(data_dir,file))
df
# Out:
#                     DateTime  01676536-A2A5-4BB7-8DA6-6E8993E3E92F  \
# 0      2019-01-01T01:00:00.0                                 1.176
# 1      2019-01-01T02:00:00.0                                 1.117
# 2      2019-01-01T03:00:00.0                                 0.825
# 3      2019-01-01T04:00:00.0                                 1.251
# 4      2019-01-01T05:00:00.0                                 1.423
# ...                      ...                                   ...
# 26298  2021-01-31T19:00:00.0                                 2.819
# 26299  2021-01-31T20:00:00.0                                 2.866
# 26300  2021-01-31T21:00:00.0                                 2.181
# 26301  2021-01-31T22:00:00.0                                 2.187
# 26302  2021-01-31T23:00:00.0                                 2.158
#
#        023010C1-B44B-4F84-AAE3-C2A77A738AEF  \
# 0                                     0.259
# 1                                     0.398
# ...

# %%
df = df.iloc[:,0:1501]
df
# Out:
#                     DateTime  01676536-A2A5-4BB7-8DA6-6E8993E3E92F  \
# 0      2019-01-01T01:00:00.0                                 1.176
# 1      2019-01-01T02:00:00.0                                 1.117
# 2      2019-01-01T03:00:00.0                                 0.825
# 3      2019-01-01T04:00:00.0                                 1.251
# 4      2019-01-01T05:00:00.0                                 1.423
# ...                      ...                                   ...
# 26298  2021-01-31T19:00:00.0                                 2.819
# 26299  2021-01-31T20:00:00.0                                 2.866
# 26300  2021-01-31T21:00:00.0                                 2.181
# 26301  2021-01-31T22:00:00.0                                 2.187
# 26302  2021-01-31T23:00:00.0                                 2.158
#
#        023010C1-B44B-4F84-AAE3-C2A77A738AEF  \
# 0                                     0.259
# 1                                     0.398
# ...

# %%
df.dtypes
# Out:
# DateTime                                 object
# 01676536-A2A5-4BB7-8DA6-6E8993E3E92F    float64
# 023010C1-B44B-4F84-AAE3-C2A77A738AEF    float64
# 025893A0-F07F-4CA4-9FC6-E86A47C132C0    float64
# 0295115A-2AD8-404B-8369-F546BC687DF9    float64
#                                          ...
# FF9A11FE-372C-43F9-A565-70DDA7C5BF28    float64
# FFBECBBF-C646-43F0-A3BB-1C3DC7946CF9    float64
# FFC850B6-B967-42C4-A11F-F3F2CD8DF75B    float64
# FFCBFBD9-0C90-4FBD-83EE-09E6AD6AC240    float64
# FFED5B43-ACCA-4A5F-9E34-D5AF3EE5956B    float64
# Length: 1501, dtype: object

# %%
#df.index = df.DateTime
#df.index = pd.to_datetime(df.index)

# %%
#df = df.iloc[:,1:]
#df

# %%
def lagged_df(lag, df):
    col_names = [df.columns[i]+"_lag{}".format(lag) for i in range(len(df.columns))]
    lagged_1 = []
    for i in df.columns:
        lagged_1.append(df[i].shift(lag).values)
    return pd.DataFrame(lagged_1, col_names).T


lag1_df = lagged_df(lag=1, df = df.iloc[:,1:])
lag1_df
# Out:
#        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag1  \
# 0                                            NaN
# 1                                          1.176
# 2                                          1.117
# 3                                          0.825
# 4                                          1.251
# ...                                          ...
# 26298                                      3.092
# 26299                                      2.819
# 26300                                      2.866
# 26301                                      2.181
# 26302                                      2.187
#
#        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag1  \
# 0                                            NaN
# 1                                          0.259
# 2                                          0.398
# 3                                          0.229
# 4                                          0.578
# ...                                          ...
# ...

# %%
lag2_df = lagged_df(lag=2, df = df.iloc[:,1:])
lag24_df = lagged_df(lag=24, df = df.iloc[:,1:])

# %%
lag2_df
# Out:
#        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag2  \
# 0                                            NaN
# 1                                            NaN
# 2                                          1.176
# 3                                          1.117
# 4                                          0.825
# ...                                          ...
# 26298                                      2.312
# 26299                                      3.092
# 26300                                      2.819
# 26301                                      2.866
# 26302                                      2.181
#
#        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag2  \
# 0                                            NaN
# 1                                            NaN
# 2                                          0.259
# 3                                          0.398
# 4                                          0.229
# ...                                          ...
# ...

# %%
lag24_df
# Out:
#        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag24  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 26298                                       2.255
# 26299                                       2.091
# 26300                                       3.340
# 26301                                       1.826
# 26302                                       1.838
#
#        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag24  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# ...

# %%
lag_df = lag1_df.join(lag2_df).join(lag24_df)

# %%
lag_df
# Out:
#        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag1  \
# 0                                            NaN
# 1                                          1.176
# 2                                          1.117
# 3                                          0.825
# 4                                          1.251
# ...                                          ...
# 26298                                      3.092
# 26299                                      2.819
# 26300                                      2.866
# 26301                                      2.181
# 26302                                      2.187
#
#        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag1  \
# 0                                            NaN
# 1                                          0.259
# 2                                          0.398
# 3                                          0.229
# 4                                          0.578
# ...                                          ...
# ...

# %%
lag_df[24:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26279 entries, 24 to 26302
# Columns: 4500 entries, 01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag1 to FFED5B43-ACCA-4A5F-9E34-D5AF3EE5956B_lag24
# dtypes: float64(4500)
# memory usage: 902.2 MB

# %%
joined_df = lag_df.join(df)
joined_df
# Out:
#        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag1  \
# 0                                            NaN
# 1                                          1.176
# 2                                          1.117
# 3                                          0.825
# 4                                          1.251
# ...                                          ...
# 26298                                      3.092
# 26299                                      2.819
# 26300                                      2.866
# 26301                                      2.181
# 26302                                      2.187
#
#        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag1  \
# 0                                            NaN
# 1                                          0.259
# 2                                          0.398
# 3                                          0.229
# 4                                          0.578
# ...                                          ...
# ...

# %%
joined_df.index = joined_df["DateTime"]

# %%
joined_df = joined_df.dropna()
joined_df
# Out:
#                        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag1  \
# DateTime
# 2019-01-31T01:00:00.0                                      2.530
# 2019-01-31T02:00:00.0                                      2.958
# 2019-01-31T03:00:00.0                                      2.496
# 2019-01-31T04:00:00.0                                      2.482
# 2019-01-31T05:00:00.0                                      1.855
# ...                                                          ...
# 2021-01-31T19:00:00.0                                      3.092
# 2021-01-31T20:00:00.0                                      2.819
# 2021-01-31T21:00:00.0                                      2.866
# 2021-01-31T22:00:00.0                                      2.181
# 2021-01-31T23:00:00.0                                      2.187
#
#                        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag1  \
# DateTime
# 2019-01-31T01:00:00.0                                      0.435
# ...

# %%
joined_df.iloc[:,3000]
# Out:
# DateTime
# 2019-01-31T01:00:00.0    2.258
# 2019-01-31T02:00:00.0    2.031
# 2019-01-31T03:00:00.0    1.935
# 2019-01-31T04:00:00.0    2.065
# 2019-01-31T05:00:00.0    1.850
#                          ...
# 2021-01-31T19:00:00.0    2.255
# 2021-01-31T20:00:00.0    2.091
# 2021-01-31T21:00:00.0    3.340
# 2021-01-31T22:00:00.0    1.826
# 2021-01-31T23:00:00.0    1.838
# Name: 01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag24, Length: 23605, dtype: float64

# %%
joined_df = joined_df.select_dtypes(exclude=['object'])
joined_df
# Out:
#                        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag1  \
# DateTime
# 2019-01-31T01:00:00.0                                      2.530
# 2019-01-31T02:00:00.0                                      2.958
# 2019-01-31T03:00:00.0                                      2.496
# 2019-01-31T04:00:00.0                                      2.482
# 2019-01-31T05:00:00.0                                      1.855
# ...                                                          ...
# 2021-01-31T19:00:00.0                                      3.092
# 2021-01-31T20:00:00.0                                      2.819
# 2021-01-31T21:00:00.0                                      2.866
# 2021-01-31T22:00:00.0                                      2.181
# 2021-01-31T23:00:00.0                                      2.187
#
#                        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag1  \
# DateTime
# 2019-01-31T01:00:00.0                                      0.435
# ...

# %%
joined_df.iloc[:,3000-1]
# Out:
# DateTime
# 2019-01-31T01:00:00.0    1.245
# 2019-01-31T02:00:00.0    1.379
# 2019-01-31T03:00:00.0    0.957
# 2019-01-31T04:00:00.0    1.415
# 2019-01-31T05:00:00.0    1.090
#                          ...
# 2021-01-31T19:00:00.0    0.447
# 2021-01-31T20:00:00.0    2.068
# 2021-01-31T21:00:00.0    4.815
# 2021-01-31T22:00:00.0    1.480
# 2021-01-31T23:00:00.0    0.878
# Name: FFED5B43-ACCA-4A5F-9E34-D5AF3EE5956B_lag2, Length: 23605, dtype: float64

# %% [markdown]
# # Amorf

# %%
#!pip install amorf

# %%
import amorf.neuralNetRegression as nnr 
from amorf.metrics import average_relative_root_mean_squared_error as arrmse

# %%
train = joined_df[joined_df.index<"2021-01-01 00:00:00"]
train
# Out:
#                        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag1  \
# DateTime
# 2019-01-31T01:00:00.0                                      2.530
# 2019-01-31T02:00:00.0                                      2.958
# 2019-01-31T03:00:00.0                                      2.496
# 2019-01-31T04:00:00.0                                      2.482
# 2019-01-31T05:00:00.0                                      1.855
# ...                                                          ...
# 2020-01-31T19:00:00.0                                      3.308
# 2020-01-31T20:00:00.0                                      2.928
# 2020-01-31T21:00:00.0                                      2.805
# 2020-01-31T22:00:00.0                                      2.519
# 2020-01-31T23:00:00.0                                      2.871
#
#                        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag1  \
# DateTime
# 2019-01-31T01:00:00.0                                      0.435
# ...

# %%
X = train.iloc[:,0:(1500*3)-1]
X
# Out:
#                        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag1  \
# DateTime
# 2019-01-31T01:00:00.0                                      2.530
# 2019-01-31T02:00:00.0                                      2.958
# 2019-01-31T03:00:00.0                                      2.496
# 2019-01-31T04:00:00.0                                      2.482
# 2019-01-31T05:00:00.0                                      1.855
# ...                                                          ...
# 2020-01-31T19:00:00.0                                      3.308
# 2020-01-31T20:00:00.0                                      2.928
# 2020-01-31T21:00:00.0                                      2.805
# 2020-01-31T22:00:00.0                                      2.519
# 2020-01-31T23:00:00.0                                      2.871
#
#                        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag1  \
# DateTime
# 2019-01-31T01:00:00.0                                      0.435
# ...

# %%
y = train.iloc[:,(1500*3):]
y
# Out:
#                        01676536-A2A5-4BB7-8DA6-6E8993E3E92F  \
# DateTime
# 2019-01-31T01:00:00.0                                 2.958
# 2019-01-31T02:00:00.0                                 2.496
# 2019-01-31T03:00:00.0                                 2.482
# 2019-01-31T04:00:00.0                                 1.855
# 2019-01-31T05:00:00.0                                 1.883
# ...                                                     ...
# 2020-01-31T19:00:00.0                                 2.928
# 2020-01-31T20:00:00.0                                 2.805
# 2020-01-31T21:00:00.0                                 2.519
# 2020-01-31T22:00:00.0                                 2.871
# 2020-01-31T23:00:00.0                                 2.643
#
#                        023010C1-B44B-4F84-AAE3-C2A77A738AEF  \
# DateTime
# 2019-01-31T01:00:00.0                                 0.479
# 2019-01-31T02:00:00.0                                 0.629
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X.values, y.values, test_size=0.2)

# %%
X_train
# Out:
# array([[1.292, 2.596, 0.882, ..., 0.729, 1.907, 0.85 ],
#        [1.422, 2.141, 0.95 , ..., 0.649, 0.274, 0.984],
#        [1.602, 0.34 , 2.979, ..., 5.416, 0.673, 1.266],
#        ...,
#        [2.094, 0.684, 1.862, ..., 0.694, 2.034, 0.572],
#        [1.122, 0.355, 1.244, ..., 0.89 , 0.262, 0.379],
#        [0.752, 0.498, 1.658, ..., 1.458, 0.615, 0.828]])

# %%
y_train
# Out:
# array([[1.058, 1.473, 1.732, ..., 0.8  , 0.294, 0.857],
#        [1.331, 0.714, 1.38 , ..., 0.182, 0.889, 0.867],
#        [1.964, 0.4  , 2.643, ..., 0.799, 0.693, 3.366],
#        ...,
#        [0.889, 0.64 , 1.523, ..., 0.964, 0.336, 1.745],
#        [1.32 , 0.563, 1.17 , ..., 0.232, 0.31 , 1.389],
#        [1.026, 0.213, 1.331, ..., 0.892, 1.151, 1.509]])

# %%
import amorf.neuralNetRegression as nnr 
from amorf.metrics import average_relative_root_mean_squared_error as arrmse
regressor = nnr.NeuralNetRegressor(patience=5, training_limit=None) #initialize neural net regressor
regressor.fit(X_train, y_train) #fit regressor to training data
prediction = regressor.predict(X_test) #predict test data 
print(arrmse(prediction, y_test)) #print error
# Out:
# Epoch: 0
# Validation Error: 19.943126678466797
# Train Error: 19.697416305541992
# Final Epochs: 21
# Final Train Error: 1.6314970254898071
# Final Validation Error: 3.8377952575683594
# 3.5017899131194747

# %%
prediction
# Out:
# array([[ 8.008153 ,  2.8655002,  5.1524396, ...,  3.4378219,  5.691886 ,
#          5.7360964],
#        [ 8.177387 ,  4.2831798,  6.5810647, ...,  4.8167415,  6.6867213,
#          6.9566445],
#        [11.3878145,  3.5786364,  6.4424915, ...,  4.045736 ,  7.558394 ,
#          7.905026 ],
#        ...,
#        [ 5.852745 ,  2.2039847,  3.4431465, ...,  2.53329  ,  4.311063 ,
#          4.43296  ],
#        [ 4.876999 ,  1.9308099,  3.2323227, ...,  2.0570755,  3.8951256,
#          3.7795093],
#        [19.100954 ,  7.0982413, 11.36271  , ...,  8.169957 , 13.343373 ,
#         14.151325 ]], dtype=float32)

# %% [markdown]
# # keras

# %%
# !pip install keras
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)

# %%
from tensorflow import keras 
#from keras.models import Sequential
#from keras.layers import Dense

# %%
train = joined_df[joined_df.index<"2021-01-01 00:00:00"]
X = train.iloc[:,0:(1500*3)-1]
y = train.iloc[:,(1500*3):]

# %%
from numpy import mean
from numpy import std
from sklearn.model_selection import RepeatedKFold
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import train_test_split, cross_val_score
 
# get the model
def get_model(n_inputs, n_outputs):
	model = Sequential()
	model.add(Dense(20, input_dim=n_inputs, kernel_initializer='he_uniform', activation='relu'))
	model.add(Dense(n_outputs))
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model
 
# evaluate a model using repeated k-fold cross-validation
def evaluate_model(X, y):
    results = list()
    n_inputs, n_outputs = X.shape[1], y.shape[1]
    # define evaluation procedure
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
    # enumerate folds
    for train_ix, test_ix in cv.split(X):
        # prepare data
        X_train, X_test = X[train_ix], X[test_ix]
        y_train, y_test = y[train_ix], y[test_ix]
        # define model
        model = get_model(n_inputs, n_outputs)
        # fit model
        model.fit(X_train, y_train, verbose=1, epochs=100)
        # evaluate model on test set
        mse = model.evaluate(X_test, y_test, verbose=0)
        # store result
        print('>%.3f' % mse)
        results.append(mse)
    return results
 
    
# evaluate a model using repeated ts-crossvalidation
def evaluate_model_tscv(X, y):
    results = list()
    n_inputs, n_outputs = X.shape[1], y.shape[1]
    # define evaluation procedure
    tscv = TimeSeriesSplit(n_splits=5)
    # enumerate folds
    for train_ix, test_ix in tscv.split(X):
        # prepare data
        X_train, X_test = X[train_ix], X[test_ix]
        y_train, y_test = y[train_ix], y[test_ix]
        # define model
        model = get_model(n_inputs, n_outputs)
        # fit model
        model.fit(X_train, y_train, verbose=1, epochs=100)
        # evaluate model on test set
        mse = model.evaluate(X_test, y_test, verbose=0)
        # store result
        print('>%.3f' % mse)
        results.append(mse)
    return results


# evaluate model
results = evaluate_model_tscv(X.values, y.values)
# summarize performance
print('MSE: %.3f (%.3f)' % (mean(results), std(results)))
# Out:
# Epoch 1/100
# 2633/2633 [==============================] - 0s 109us/step - loss: 2.7229
# Epoch 2/100
# 2633/2633 [==============================] - 0s 65us/step - loss: 1.5205
# Epoch 3/100
# 2633/2633 [==============================] - 0s 66us/step - loss: 1.5064
# Epoch 4/100
# 2633/2633 [==============================] - 0s 66us/step - loss: 1.4654
# Epoch 5/100
# 2633/2633 [==============================] - 0s 67us/step - loss: 1.3602
# Epoch 6/100
# 2633/2633 [==============================] - 0s 67us/step - loss: 1.3085
# Epoch 7/100
# 2633/2633 [==============================] - 0s 68us/step - loss: 1.2969
# Epoch 8/100
# 2633/2633 [==============================] - 0s 74us/step - loss: 1.2925
# Epoch 9/100
# 2633/2633 [==============================] - 0s 71us/step - loss: 1.2891
# Epoch 10/100
# 2633/2633 [==============================] - 0s 67us/step - loss: 1.2838
# Epoch 11/100
# 2633/2633 [==============================] - 0s 67us/step - loss: 1.2752
# Epoch 12/100
# ...

# %%
##

# %%
file_2 = 'test1.csv'
data_dir_2= r'C:\Users\54651\Downloads\microsoft fclib\forecasting\smeco data'
df2 = pd.read_csv(os.path.join(data_dir_2,file2))
df2
# Out:
#                      DateTime                               Premise    kWh  \
# 0        2021-03-01T00:00:00Z  00210658-581E-4586-AA28-1A1354D5E5F5  1.914
# 1        2021-03-01T01:00:00Z  00210658-581E-4586-AA28-1A1354D5E5F5  1.501
# 2        2021-03-01T02:00:00Z  00210658-581E-4586-AA28-1A1354D5E5F5  0.901
# 3        2021-03-01T03:00:00Z  00210658-581E-4586-AA28-1A1354D5E5F5  0.920
# 4        2021-03-01T04:00:00Z  00210658-581E-4586-AA28-1A1354D5E5F5  1.381
# ...                       ...                                   ...    ...
# 1573999  2021-03-21T19:00:00Z  FFED5B43-ACCA-4A5F-9E34-D5AF3EE5956B  1.273
# 1574000  2021-03-21T20:00:00Z  FFED5B43-ACCA-4A5F-9E34-D5AF3EE5956B  1.955
# 1574001  2021-03-21T21:00:00Z  FFED5B43-ACCA-4A5F-9E34-D5AF3EE5956B  0.888
# 1574002  2021-03-21T22:00:00Z  FFED5B43-ACCA-4A5F-9E34-D5AF3EE5956B  1.905
# 1574003  2021-03-21T23:00:00Z  FFED5B43-ACCA-4A5F-9E34-D5AF3EE5956B  3.144
#
#          temp_outdoor
# 0               46.40
# ...

# %%
##

# %%
test = joined_df[joined_df.index>"2021-01-01 00:00:00"]
X_test = test.iloc[:,0:(1500*3)-1]
Y_test = test.iloc[:,(1500*3):]

# %%
X_test
# Out:
#                        01676536-A2A5-4BB7-8DA6-6E8993E3E92F_lag1  \
# DateTime
# 2021-01-01T00:00:00.0                                      2.643
# 2021-01-01T01:00:00.0                                      2.985
# 2021-01-01T02:00:00.0                                      3.117
# 2021-01-01T03:00:00.0                                      2.246
# 2021-01-01T04:00:00.0                                      2.528
# ...                                                          ...
# 2021-01-31T19:00:00.0                                      3.092
# 2021-01-31T20:00:00.0                                      2.819
# 2021-01-31T21:00:00.0                                      2.866
# 2021-01-31T22:00:00.0                                      2.181
# 2021-01-31T23:00:00.0                                      2.187
#
#                        023010C1-B44B-4F84-AAE3-C2A77A738AEF_lag1  \
# DateTime
# 2021-01-01T00:00:00.0                                      0.372
# ...

# %%
Y_test
# Out:
#                        01676536-A2A5-4BB7-8DA6-6E8993E3E92F  \
# DateTime
# 2021-01-01T00:00:00.0                                 2.985
# 2021-01-01T01:00:00.0                                 3.117
# 2021-01-01T02:00:00.0                                 2.246
# 2021-01-01T03:00:00.0                                 2.528
# 2021-01-01T04:00:00.0                                 2.180
# ...                                                     ...
# 2021-01-31T19:00:00.0                                 2.819
# 2021-01-31T20:00:00.0                                 2.866
# 2021-01-31T21:00:00.0                                 2.181
# 2021-01-31T22:00:00.0                                 2.187
# 2021-01-31T23:00:00.0                                 2.158
#
#                        023010C1-B44B-4F84-AAE3-C2A77A738AEF  \
# DateTime
# 2021-01-01T00:00:00.0                                 0.327
# 2021-01-01T01:00:00.0                                 0.573
# ...

# %%
#prediction
n_inputs, n_outputs = X_train.shape[1], y_train.shape[1]
model = model = get_model(n_inputs, n_outputs)
model.fit(X_train, y_train, verbose=0, epochs=100)

# %%
model.save('14042022.h5')

# %%
# !conda install -c anaconda 'h5py==2.10.0'
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\54651\Anaconda3\envs\forecasting_env
#
#   added / updated specs:
#     - h5py==2.10.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     h5py-2.10.0                |   py36h5e291fa_0         992 KB  anaconda
#     hdf5-1.10.4                |       h7ebc959_0        19.2 MB  anaconda
#     pyreadline-2.1             |           py36_1         141 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        20.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   h5py               anaconda/win-64::h5py-2.10.0-py36h5e291fa_0
#   hdf5               anaconda/win-64::hdf5-1.10.4-h7ebc959_0
#   pyreadline         anaconda/win-64::pyreadline-2.1-py36_1
#
# ...

# %%
# !pip install 'h5py==2.10.0' --force-reinstall
# Out:
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# ERROR: Invalid requirement: "'h5py==2.10.0'"
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)

# %%
# !pip install h5py==2.9.0
# Out:
# ...
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\54651\\anaconda3\\envs\\forecasting_env\\lib\\site-packages\\~5py\\defs.cp36-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -umpy (c:\users\54651\anaconda3\envs\forecasting_env\lib\site-packages)
# ...

# %%
from keras.models import load_model

model.save('my_model.h5')  # creates a HDF5 file 'my_model.h5'
del model  # deletes the existing model

# returns a compiled model
# identical to the previous one
model = load_model('my_model.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-ec53bbfc414f> in <module>
#       6 # returns a compiled model
#       7 # identical to the previous one
# ----> 8 model = load_model('my_model.h5')
#
# ~\Anaconda3\envs\forecasting_env\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# ~\Anaconda3\envs\forecasting_env\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
# ...

# %%
from keras.models import load_model
# returns a compiled model
# identical to the previous one
model = load_model('14042022.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-f9fc096420a2> in <module>
#       2 # returns a compiled model
#       3 # identical to the previous one
# ----> 4 model = load_model('14042022.h5')
#
# ~\Anaconda3\envs\forecasting_env\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# ~\Anaconda3\envs\forecasting_env\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
# ...

# %%
import os
directory_path = os.getcwd()

# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# later...
import h5py
from keras.models import load_model
from keras.models import model_from_json
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-cd91453723bb> in <module>
#       9 loaded_model = model_from_json(loaded_model_json)
#      10 # load weights into new model
# ---> 11 loaded_model.load_weights("model.h5")
#      12 print("Loaded model from disk")
#
# ~\Anaconda3\envs\forecasting_env\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# ~\Anaconda3\envs\forecasting_env\lib\site-packages\keras\engine\network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1228             else:
#    1229                 saving.load_weights_from_hdf5_group(
# -> 1230                     f, self.layers, reshape=reshape)
# ...

# %%
loaded_model

# %%
# It can be used to reconstruct the model identically.
reconstructed_model = keras.models.load_model(r"14042022")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-107224365b0a> in <module>
#       1 # It can be used to reconstruct the model identically.
# ----> 2 reconstructed_model = keras.models.load_model(r"14042022")
#
# ~\Anaconda3\envs\forecasting_env\lib\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~\Anaconda3\envs\forecasting_env\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     164     if model_config is None:
# ...

# %%
model.predict(X_test)
# Out:
# array([[2.4658947 , 0.36832306, 2.315522  , ..., 0.22888371, 0.91299736,
#         2.2064579 ],
#        [2.2765553 , 0.33627173, 2.2664514 , ..., 0.18540516, 0.75234175,
#         2.0583565 ],
#        [2.0993037 , 0.35099065, 2.1094112 , ..., 0.25310034, 0.70370233,
#         1.9376402 ],
#        ...,
#        [2.2470043 , 0.40629116, 1.7427536 , ..., 0.40365088, 0.99479747,
#         2.1810024 ],
#        [2.2453368 , 0.4240381 , 1.7067627 , ..., 0.4229319 , 0.9685236 ,
#         2.138771  ],
#        [1.8386277 , 0.35551926, 1.5764178 , ..., 0.362308  , 0.7247963 ,
#         1.8473775 ]], dtype=float32)

# %%
pred_df = pd.DataFrame(model.predict(X_test))
pred_df
# Out:
#           0         1         2         3         4         5         6     \
# 0     2.465895  0.368323  2.315522  2.161386  2.000324  3.038249  5.673041
# 1     2.276555  0.336272  2.266451  2.170043  1.845773  3.047575  5.396730
# 2     2.099304  0.350991  2.109411  2.015799  1.857991  2.774516  5.261330
# 3     2.013992  0.386033  2.082520  1.979190  1.929276  2.686039  5.255676
# 4     1.724074  0.334833  1.944018  1.884458  1.639110  2.642384  5.292573
# ...        ...       ...       ...       ...       ...       ...       ...
# 7827  1.801441  0.392777  1.651159  1.439750  1.828936  2.056912  6.196388
# 7828  2.131727  0.412447  1.724184  1.401328  2.059158  2.024534  5.770056
# 7829  2.247004  0.406291  1.742754  1.291551  2.110972  2.012352  4.923576
# 7830  2.245337  0.424038  1.706763  1.254409  2.216107  1.876209  4.604201
# 7831  1.838628  0.355519  1.576418  1.047414  1.768753  1.949382  4.073772
#
# ...

# %%
results
# Out:
# [0.6598221927843468,
#  0.6870958891205008,
#  0.7048612366157793,
#  0.6954690893012357,
#  0.7129557810029276,
#  0.6697440026074024,
#  0.6805417095473392,
#  0.6996794267402242,
#  0.676618566298379,
#  0.6875357371232294,
#  0.6741851519873538,
#  0.6893983752253089,
#  0.6837390978526706,
#  0.699651236691351,
#  0.6948772507826588,
#  0.6829929072114586,
#  0.707913740080372,
#  0.7065862270571721,
#  0.6768232456248398,
#  0.667964068824306,
#  0.714819275380994,
#  0.6822221000384922,
#  0.6708086194194315,
#  0.6969029482739896,
#  0.667142807001091,
#  0.6914462470600101,
#  0.7024892096135461,
#  0.6856530884737899,
#  0.6870360989017281,
#  0.6954864498627057]
